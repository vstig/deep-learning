# %%
import utils as ut
from keras.applications.resnet50 import ResNet50

# %matplotlib inline

# %%
import os
import sys
sys.path.append('/usr/local/lib/python2.7/site-packages')
import cv2

# %% [markdown]
# ## Playing Around w/ Object Recognition

# %%
model = ResNet50(weights='imagenet')

# %%
img_path = '/Users/vincentstigliani/Downloads/baboon.jpg'

img = ut.get_image_from_path(img_path)
top = ut.identify_picture(model, img)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x13029F990>
# Prediction: baboon	Likelihood: 98.2%
# Prediction: macaque	Likelihood: 1.8%
# Prediction: guenon	Likelihood: 0.0%

# %%
img_path = '/Users/vincentstigliani/Downloads/kiwi.jpg'

img = ut.get_image_from_path(img_path)
top = ut.identify_picture(model, img)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x12181DE90>
# Prediction: jackfruit	Likelihood: 48.7%
# Prediction: orange	Likelihood: 29.6%
# Prediction: lemon	Likelihood: 13.8%

# %%
reload(ut)
# Out:
# <module 'utils' from 'utils.py'>

# %%
webcam_img = ut.get_webcam_img()
webcam_img = identify_picture(model, 'tmp.jpg')

os.system("say 'I think I am seeing a {}.  I am {:0.1f} percent sure' &".format(webcam_img[1], webcam_img[2]*100))
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x1161431D0>
# Prediction: acoustic_guitar	Likelihood: 53.4%
# Prediction: electric_guitar	Likelihood: 24.2%
# Prediction: sax	Likelihood: 2.0%
# 0

# %%
ut.what_is_in_front_of_you(model)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x110F22C50>
# Prediction: bolo_tie	Likelihood: 8.1%
# Prediction: stole	Likelihood: 7.6%
# Prediction: cardigan	Likelihood: 6.5%
